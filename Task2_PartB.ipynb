# %%
import pandas as pd
import csv
import numpy as np

import requests
from io import StringIO
from IPython.display import display
from random import shuffle
from itertools import combinations
import time

# %% [markdown]
# Task 2 Part 2
#
# *  Concatenate the values in each record into one single string.
# *  Change all alphabetical characters into lowercase.
#
# *  Convert multiple spaces to one.
# *  Combine the records from both tables into one big list.
# *  Use the functions in the tutorials from lab 5 to compute the shingles, the
#   minhash signature and the similarity.
# * Extract the top 2224
#  candidates from the LSH algorithm, compare them to the actual mappings in the file DBLP-ACM_perfectMapping.csv and compute the precision of the method.
# *   Record the running time of the method.
# *   Compare the precision and the running time in Parts 1 and 2.

# %%
#Timing method
start_time_part2 = time.time()

# Load the datasets
df_ACM = pd.read_csv('ACM.csv', header=0, quotechar='"', sep=",", na_values=['na', '-', '.', ''])
df_DBLP2 = pd.read_csv('DBLP2.csv', header=0, quotechar='"', sep=",", encoding="ISO-8859-1", na_values=['na', '-', '.', ''])

#Checking datasete
head_ACM = df_ACM.head()
head_DBLP2 = df_DBLP2.head()

print("Head of ACM dataset:")
print(head_ACM)

print("\nHead of DBLP2 dataset:")
print(head_DBLP2)
# Out:
# Head of ACM dataset:
#        id                                              title  \
# 0  304586  The WASA2 object-oriented workflow management ...
# 1  304587  A user-centered interface for querying distrib...
# 2  304589  World Wide Database-integrating the Web, CORBA...
# 3  304590           XML-based information mediation with MIX
# 4  304582  The CCUBE constraint object-oriented database ...
#
#                                              authors  \
# 0                    Gottfried Vossen, Mathias Weske
# 1                  Isabel F. Cruz, Kimberly M. James
# 2  Athman Bouguettaya, Boualem Benatallah, Lily H...
# 3  Chaitan Baru, Amarnath Gupta, Bertram Lud&#228...
# 4  Alexander Brodsky, Victor E. Segal, Jia Chen, ...
#
#                                             venue  year
# 0  International Conference on Management of Data  1999
# 1  International Conference on Management of Data  1999
# 2  International Conference on Management of Data  1999
# 3  International Conference on Management of Data  1999
# 4  International Conference on Management of Data  1999
#
# Head of DBLP2 dataset:
#                          id  \
# 0  journals/sigmod/Mackay99
# 1      conf/vldb/PoosalaI96
# 2   conf/vldb/PalpanasSCP02
# 3    conf/vldb/GardarinGT96
# 4         conf/vldb/HoelS95
#
#                                                title  \
# 0  Semantic Integration of Environmental Models f...
# 1  Estimation of Query-Result Distribution and it...
# 2  Incremental Maintenance for Non-Distributive A...
# 3  Cost-based Selection of Path Expression Proces...
# 4  Benchmarking Spatial Join Operations with Spat...
#
#                                              authors          venue  year
# 0                                    D. Scott Mackay  SIGMOD Record  1999
# 1             Viswanath Poosala, Yannis E. Ioannidis           VLDB  1996
# 2  Themistoklis Palpanas, Richard Sidle, Hamid Pi...           VLDB  2002
# 3  Zhao-Hui Tang, Georges Gardarin, Jean-Robert G...           VLDB  1996
# 4                          Erik G. Hoel, Hanan Samet           VLDB  1995

# %%
#Checking for missing values
missing_values_ACM = df_ACM.isna().sum()
missing_values_DBLP2 = df_DBLP2.isna().sum()

print("Missing values in ACM dataset:")
print(missing_values_ACM)

print("\nMissing values in DBLP2 dataset:")
print(missing_values_DBLP2)

#Dropping missing values before combining records into single string
#In order to not fuck up the data, the missing values are deleted before imputing the new attribute. Since the author attribute has 14 missing values in ACM, this would have resulted in incomplete data. Dit meot in word <<<
df_ACM.dropna(inplace=True)
df_DBLP2.dropna(inplace=True)

# Concatenate values in each record into one single string
df_ACM['combined'] = df_ACM.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
df_DBLP2['combined'] = df_DBLP2.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
# Out:
# Missing values in ACM dataset:
# id          0
# title       0
# authors    14
# venue       0
# year        0
# dtype: int64
#
# Missing values in DBLP2 dataset:
# id         0
# title      0
# authors    0
# venue      0
# year       0
# dtype: int64

# %%
#Change all alphabetical characters into lowercase
df_ACM['combined'] = df_ACM['combined'].str.lower()
df_DBLP2['combined'] = df_DBLP2['combined'].str.lower()

# %%
#Convert multiple spaces to one.
df_ACM['combined'] = df_ACM['combined'].str.replace('\s+', ' ', regex=True)
df_DBLP2['combined'] = df_DBLP2['combined'].str.replace('\s+', ' ', regex=True)

# %%
#Combine the records from both tables into one big list
combined_data = pd.concat([df_ACM['combined'], df_DBLP2['combined']], ignore_index=True)

#Checking the count of records and the df
count_combined = combined_data.count()

print("Count of records in combined dataset:")
print(count_combined)

count_combined_df = combined_data.to_frame()
print("\nCombined dataset:")
print(count_combined_df)

#Put data into a frame
combined_data = combined_data.to_frame()
combined_data.head()
# Out:
# Count of records in combined dataset:
# 4896
#
# Combined dataset:
#                                                combined
# 0     304586 the wasa2 object-oriented workflow mana...
# 1     304587 a user-centered interface for querying ...
# 2     304589 world wide database-integrating the web...
# 3     304590 xml-based information mediation with mi...
# 4     304582 the ccube constraint object-oriented da...
# ...                                                 ...
# 4891  journals/tods/karpsp03 a simple algorithm for ...
# 4892  conf/vldb/limwv03 sash: a self-adaptive histog...
# 4893  journals/tods/chakrabartikmp02 locally adaptiv...
# 4894  journals/sigmod/snodgrass01 chair's message ri...
# 4895  conf/vldb/lim01 indexing and querying xml data...
#
# [4896 rows x 1 columns]
#                                             combined
# 0  304586 the wasa2 object-oriented workflow mana...
# 1  304587 a user-centered interface for querying ...
# 2  304589 world wide database-integrating the web...
# 3  304590 xml-based information mediation with mi...
# 4  304582 the ccube constraint object-oriented da...

# %%
#For step 6 the ID's will be listed.
combined_data_with_id = list(zip(df_ACM['id'], df_ACM['combined'])) + list(zip(df_DBLP2['id'], df_DBLP2['combined']))
combined_data_with_id[:5]
# Out:
# [(304586,
#   '304586 the wasa2 object-oriented workflow management system gottfried vossen, mathias weske international conference on management of data 1999'),
#  (304587,
#   '304587 a user-centered interface for querying distributed multimedia databases isabel f. cruz, kimberly m. james international conference on management of data 1999'),
#  (304589,
#   '304589 world wide database-integrating the web, corba and databases athman bouguettaya, boualem benatallah, lily hendra, james beard, kevin smith, mourad quzzani international conference on management of data 1999'),
#  (304590,
#   '304590 xml-based information mediation with mix chaitan baru, amarnath gupta, bertram lud&#228;scher, richard marciano, yannis papakonstantinou, pavel velikhov, vincent chu international conference on management of data 1999'),
#  (304582,
#   '304582 the ccube constraint object-oriented database system alexander brodsky, victor e. segal, jia chen, paval a. exarkhopoulo international conference on management of data 1999')]

# %% [markdown]
# Compute the shingles, the minhash signature and the similarity.

# %%
#Shingles
def shingle(text, k=5):
    return {text[i:i + k] for i in range(len(text) - k + 1)}

shingled_list = [shingle(text) for _, text in combined_data_with_id]
print(shingled_list[:5])
# Out:
# [{'ta 19', 'natio', 'ject-', 'ement', 'nfere', ' conf', ' math', 'orkfl', 'ried ', 'f dat', 't of ', 'en, m', 'ional', 'terna', 'feren', ' obje', 'nal c', 'vosse', 'n man', ' on m', 'm got', 'as we', 'sa2 o', 'mathi', 't-ori', 'e was', 'ske i', '586 t', 'ment ', 'manag', 'ied v', 'tiona', 'rkflo', 'd vos', 'al co', 'ossen', ' of d', 'orien', 'ystem', 'sen, ', 'the w', 'd wor', 'ect-o', 'ias w', 'stem ', 'anage', ' work', 'ata 1', 'nce o', 'nted ', 'tfrie', 'l con', 'objec', 'ottfr', 'bject', 'of da', 'nt of', 'rence', ' wasa', 'tem g', '2 obj', ' inte', 's wes', 'rient', 'confe', '6 the', 'thias', 'workf', ', mat', 'inter', 'ed wo', '30458', ' data', 'ssen,', ' the ', 'ce on', '-orie', 'n, ma', 'ntern', 'he wa', 'em go', 'rnati', 'flow ', 'athia', 'ent o', 'e on ', 'data ', 'ence ', 'hias ', 'ation', 'ke in', 't sys', 'ow ma', 'nt sy', '4586 ', 'a 199', 'eske ', 'ageme', 'weske', 'wasa2', ' mana', 'asa2 ', 'low m', 'a2 ob', ' gott', 'syste', 'kflow', 'gemen', 'onal ', 'erenc', 'fried', 'w man', ' syst', 'gottf', 'ttfri', 'ted w', 'on ma', 'ent s', '04586', '86 th', 'ernat', 'ented', ' voss', 'ct-or', 'onfer', ' 1999', ' wesk', 'iente', 'e int', 'ed vo', 'nagem'}, {'ta 19', 'tered', 'natio', 'es in', 'ement', 'nfere', 'ueryi', 'ed mu', 'terfa', ' conf', 'f dat', 'rly m', 'ataba', 't of ', 'ional', 'd mul', 'terna', 'mberl', 'uz, k', 'ed in', 'r-cen', ' for ', 'user-', ' dist', 'nal c', 'feren', 'cente', 'n man', ' on m', 'd int', 'rying', 'imedi', 'ment ', 'manag', 'tiona', 'face ', 'nterf', 'f. cr', 'al co', ', kim', 'ibute', 'tribu', ' of d', 'ered ', 'mes i', 'a dat', '-cent', 'anage', 'ata 1', 'nce o', 'erfac', 'ames ', 'distr', '587 a', 'ruz, ', 'ing d', 'l con', 's int', 'of da', 'y m. ', 'nt of', 's isa', 'rence', ' inte', 'ng di', 'ying ', 'cruz,', ' quer', 'ser-c', 'confe', 'l f. ', ' kimb', '4587 ', 'bases', 'imber', 'ases ', 'ace f', 'uted ', 'inter', 'buted', 'red i', '30458', ' data', '. jam', ' jame', 'ly m.', 'berly', 'ce on', 'timed', 'ntern', '. cru', 'm. ja', ' isab', 'rnati', '87 a ', 'ent o', 'e on ', 'data ', 'erly ', 'er-ce', 'kimbe', 'ence ', '7 a u', 'media', 'ation', 'enter', 'istri', ' f. c', 'strib', 'ribut', 'eryin', 'datab', 'multi', 'ltime', 'ses i', 'james', ' a us', 'ia da', 'a 199', 'rface', ' user', 'edia ', 'tabas', 'abel ', 'ageme', 'ntere', 'for q', ' mana', ' mult', 'g dis', 'sabel', '04587', 'ultim', 'gemen', ' m. j', 'onal ', 'es is', 'query', 'erenc', 'bel f', 'on ma', 'ted m', 'a use', 'z, ki', 'ce fo', 'ernat', 'abase', 'el f.', 'onfer', 'e for', 'r que', ' cruz', ' 1999', 'dia d', 'isabe', 'or qu', 'nagem'}, {'ta 19', 'natio', 's bea', ', lil', 'ement', 'boual', 'nfere', ' conf', 'ratin', '589 w', 'taya,', 'f dat', ', cor', ' web,', 'moura', 'ataba', 'ating', 't of ', 'ional', 'ya, b', 'ase-i', 'terna', 'feren', '4589 ', ' worl', 'nal c', 'n man', ' wide', ' on m', 'smith', 'rad q', ' bena', ' quzz', ', kev', 'uguet', 'ettay', 'lily ', 'd wid', 'atall', 'kevin', 'evin ', 'ment ', 'orld ', 'manag', 'ttaya', 'orba ', 'tiona', 'al co', 'i int', 'ourad', ' of d', 'web, ', 'wide ', 'ing t', 'ng th', 'the w', 'ualem', ', bou', 'th, m', 'a and', '-inte', 'an bo', 'anage', 'ata 1', 'nce o', 'urad ', 'grati', 'ames ', 'es be', 'world', 'l con', 'of da', 'nt of', 'beard', 'benat', 'rence', 'guett', ' inte', 'se-in', 'man b', 'ily h', ' hend', ' bear', ' boua', 'mith,', 'he we', 'vin s', 'de da', 'y hen', 'uzzan', 'ld wi', 'ting ', ' and ', 'ide d', 'integ', 'confe', 'ses a', 'endra', 'bases', 'ougue', 'ases ', 'bougu', ' kevi', 'inter', 'lem b', 'zzani', 'g the', '30458', 'eb, c', ' data', 'eard,', 'ntegr', ' the ', ', mou', ' jame', 'ouale', 'ce on', ' corb', 'em be', 'ntern', 'a, bo', 'thman', 'ni in', 'ndra,', 'd dat', 'rd, k', 'rnati', ' boug', 'zani ', 'mes b', 'ent o', 'athma', 'allah', 'hman ', 'egrat', '9 wor', 'e on ', 'ra, j', 'data ', 'corba', 'n smi', 'enata', '04589', 'ence ', 'ation', 'h, li', 'datab', 'alem ', 's ath', 'n bou', 'and d', 'tegra', 'base-', 'b, co', 'ly he', 'h, mo' ...

# %%
#Function for vocab
def build_vocab(shingle_sets: list)->dict:
    full_set = {item for set_ in shingle_sets for item in set_}
    vocab = {}
    for i, shingle in enumerate(list(full_set)):
        vocab[shingle] = i
    return vocab
#Function for one_hot encoded vector from shingles list
def one_hot(shingles: set, vocab: dict):
    vec = np.zeros(len(vocab))
    for shingle in shingles:
        idx = vocab[shingle]
        vec[idx] = 1
    return vec

vocab = build_vocab(shingled_list)
document_shingle_matrix = [one_hot(s, vocab) for s in shingled_list]

# %%
def get_minhash_arr(num_hashes:int,vocab:dict):
    length = len(vocab.keys())
    arr = np.zeros((num_hashes,length))
    for i in range(num_hashes):
        permutation = np.random.permutation(len(vocab.keys())) + 1
        arr[i,:] = permutation.copy()
    return arr.astype(int)

def get_signature(minhash:np.ndarray, vector:np.ndarray):
    idx = np.nonzero(vector)[0].tolist()
    shingles = minhash[:,idx]
    signature = np.min(shingles,axis=1)
    return signature

def jaccard_similarity(set1, set2):
    intersection_size = len(set1.intersection(set2))
    union_size = len(set1.union(set2))
    return intersection_size / union_size if union_size != 0 else 0.0

def compute_signature_similarity(signature_1, signature_2):
    if signature_1.shape != signature_2.shape:
        raise ValueError("Both signature matrices must have the same shape.")
    agreement_count = np.sum(signature_1 == signature_2)
    similarity = agreement_count / signature_2.shape[0]

    return similarity

# %%
# Step 1: Generate the MinHash Array
num_hashes = 500  # The number of hash functions to use for MinHash
minhash_array = get_minhash_arr(num_hashes, vocab)

# Step 2: Compute MinHash Signatures for all documents
signatures = [get_signature(minhash_array, vec) for vec in document_shingle_matrix]

# Step 3: Compute Similarities (for demonstration, we'll compute similarity between the first two documents)
# Estimated Jaccard similarity using MinHash signatures
similarity_estimate = compute_signature_similarity(signatures[0], signatures[1])

# Actual Jaccard similarity between the original shingle sets
actual_similarity = jaccard_similarity(shingled_list[0], shingled_list[1])

print(f"Estimated Jaccard Similarity: {similarity_estimate}")
print(f"Actual Jaccard Similarity: {actual_similarity}")
# Out:
# Estimated Jaccard Similarity: 0.174
# Actual Jaccard Similarity: 0.20502092050209206

# %%
#LSH funtcion:
class LSH:
    buckets = []
    counter = 0

    def __init__(self, b: int):
        self.b = b
        for i in range(b):
            self.buckets.append({})

    def make_subvecs(self, signature: np.ndarray) -> np.ndarray:
        l = len(signature)
        assert l % self.b == 0
        r = int(l / self.b)
        subvecs = []
        for i in range(0, l, r):
            subvecs.append(signature[i:i+r])
        return np.stack(subvecs)

    def add_hash(self, signature: np.ndarray):
        subvecs = self.make_subvecs(signature).astype(str)
        for i, subvec in enumerate(subvecs):
            subvec = ','.join(subvec)
            if subvec not in self.buckets[i].keys():
                self.buckets[i][subvec] = []
            self.buckets[i][subvec].append(self.counter)
        self.counter += 1

    def check_candidates(self) -> set:

        candidates = []
        for bucket_band in self.buckets:
            keys = bucket_band.keys()
            for bucket in keys:
                hits = bucket_band[bucket]
                if len(hits) > 1:
                    candidates.extend(combinations(hits, 2))
        return set(candidates)

# %%
b = 10   # number of buckets
lsh = LSH(b)
for signature in signatures:
    lsh.add_hash(signature)
candidate_pairs = lsh.check_candidates()
len(candidate_pairs)
# Out:
# 2

# %%
for candidate in list(candidate_pairs)[:5]:
    print("Candidate similar sentence are:")
    print(sentences[candidate[0]])
    print(sentences[candidate[1]])
    print("="*10)
# Out:
# Candidate similar sentence are:
# 564799 database tuning: principles, experiments, and troubleshooting techniques (part ii) dennis shasha, philippe bonnet international conference on management of data 2002
# 564798 database tuning: principles, experiments, and troubleshooting techniques (part i) dennis shasha, philippe bonnet international conference on management of data 2002
# ==========
# Candidate similar sentence are:
# journals/sigmod/liu02 editor's notes ling liu sigmod record 2002
# journals/sigmod/liu02c editor's notes ling liu sigmod record 2002
# ==========

# %%
df_PerfectMapping = pd.read_csv('DBLP-ACM_perfectMapping.csv', header=0, quotechar='"', sep=",", na_values=['na', '-', '.', ''])
df_PerfectMapping.head()
# Out:
#                        idDBLP   idACM
# 0  conf/sigmod/SlivinskasJS01  375678
# 1   conf/sigmod/ChaudhuriDN01  375694
# 2     conf/sigmod/RinfretOO01  375669
# 3    conf/sigmod/BreunigKKS01  375672
# 4   conf/sigmod/JagadishJOT01  375687

# %%
actual_mappings = set(tuple(rec) for rec in df_PerfectMapping[['idACM', 'idDBLP']].to_records(index=False))
# First, determine the split index where ACM data ends and DBLP2 data begins
split_index = len(df_ACM)

# Filter the candidates to ensure that one ID is from ACM and the other is from DBLP2
filtered_candidates = [(i, j) for i, j in candidates if i < split_index and j >= split_index]

# Get the top 2224 candidates from the filtered list
top_candidates_filtered = filtered_candidates[:2224]

# Construct top_candidates_ids_adjusted using the filtered candidate pairs
top_candidates_ids_adjusted = {(combined_data_with_id[i][0], combined_data_with_id[j][0]) for i, j in top_candidates_filtered}

# Compute precision using the adjusted top_candidates_ids
correct_candidates_adjusted = actual_mappings.intersection(top_candidates_ids_adjusted)
precision_adjusted = len(correct_candidates_adjusted) / len(top_candidates_ids_adjusted)

print(f"Adjusted Precision: {precision_adjusted:.4f}")
print("Correctly identified pairs:", correct_candidates_adjusted)
print(len(correct_candidates_adjusted))

#ending time
end_time_part2 = time.time()
# Out:
# Adjusted Precision: 0.9766
# Correctly identified pairs: {(383736, 'journals/tods/DekhtyarRS01'), (262767, 'journals/sigmod/JukicV97'), (672004, 'conf/vldb/SrinivasanDFCJYKTDB00'), (673485, 'conf/vldb/GardarinST96'), (202668, 'journals/sigmod/Chaudhri95'), (872837, 'conf/sigmod/GotoK03'), (673146, 'conf/vldb/SistlaYLL95'), (362140, 'journals/sigmod/LeeC00'), (191942, 'conf/sigmod/Vaskevitch94'), (191933, 'conf/sigmod/LaursenOP94'), (671172, 'conf/vldb/AbiteboulMRVW98'), (640993, 'journals/sigmod/Chang03'), (670997, 'conf/vldb/GinisHKMT97'), (219774, 'journals/sigmod/Stacey95'), (637415, 'journals/sigmod/BusslerFM02'), (248618, 'journals/sigmod/Qian97'), (234895, 'journals/sigmod/BrunieK96'), (673328, 'conf/vldb/FaloutsosMS96'), (381893, 'journals/sigmod/FreemanG96'), (671701, 'conf/vldb/AgrawalCN00'), (248606, 'journals/sigmod/TomasicS97'), (564714, 'conf/sigmod/PapakonstantinouPV02'), (582412, 'journals/tods/CiacciaP02'), (671015, 'conf/vldb/LeeLWS97'), (959079, 'journals/sigmod/WangD03'), (641274, 'journals/vldb/HuntAI02'), (369284, 'journals/sigmod/Halevy00'), (245885, 'journals/sigmod/Date96'), (344869, 'journals/sigmod/VassiliadisS99'), (273257, 'journals/sigmod/KuokFW98'), (945729, 'journals/sigmod/AbererCDDHPS03'), (253357, 'conf/sigmod/LlirbatFS97'), (673138, 'conf/vldb/SubietaKL95'), (776989, 'journals/sigmod/MukhopadhyayGS03'), (673327, 'conf/vldb/Hess96'), (362137, 'journals/sigmod/WestmannKHM00'), (671194, 'conf/vldb/RezendeH98'), (219727, 'journals/sigmod/DunhamH95a'), (671851, 'conf/vldb/ChakrabartiGRS00'), (381881, 'journals/sigmod/AndlerHEMBE96'), (336568, 'conf/sigmod/Galhardas00'), (671351, 'conf/vldb/Johnson99'), (603876, 'journals/sigmod/LudascherMM01'), (673321, 'conf/vldb/PoosalaI96'), (344819, 'journals/sigmod/EisenbergM00'), (777004, 'journals/sigmod/AilamakiG03'), (640992, 'journals/sigmod/GottlobKP03'), (671679, 'conf/vldb/ChoG00'), (223850, 'conf/sigmod/LuMSS95'), (671349, 'conf/vldb/McHughW99'), (276323, 'conf/sigmod/Cohen98'), (357778, 'journals/tods/ParsonsW00'), (306133, 'journals/sigmod/ChristoffelPSL98'), (245886, 'journals/sigmod/Darwen96'), (233342, 'conf/sigmod/PoosalaIHS96'), (333611, 'journals/sigmod/RosenthalS99'), (959070, 'journals/sigmod/DemersGRTY03'), (671519, 'conf/vldb/TanGO99'), (673486, 'conf/vldb/Sacks-Davis96'), (248608, 'journals/sigmod/RiekertMW97'), (248617, 'journals/sigmod/DoanPSB97'), (672207, 'conf/vldb/StanoiRAA01'), (564743, 'conf/sigmod/Aggarwal02'), (672033, 'conf/vldb/Wadler01'), (187447, 'journals/sigmod/YeungHL94'), (959080, 'journals/sigmod/GalianoM03'), (304200, 'conf/sigmod/LeeKC99'), (176570, 'journals/tods/ScioreSR94'), (765752, 'journals/vldb/SivasankaranSTPR96'), (671005, 'conf/vldb/CiacciaPZ97'), (673330, 'conf/vldb/BouganimFV96'), (671860, 'conf/vldb/PardonA00'), (276373, 'conf/sigmod/Kennamer98'), (671342, 'conf/vldb/SheikholeslamiCZ98'), (223798, 'conf/sigmod/PapadiasTSE95'), (672820, 'conf/vldb/MuntzR94'), (776992, 'journals/sigmod/CaleroPR03'), (604267, 'journals/sigmod/StolfoLCFE01'), (640994, 'journals/sigmod/WenLMZ03'), (673660, 'conf/vldb/WhiteheadSM97'), (245898, 'journals/sigmod/SantucciT96'), (381860, 'journals/sigmod/Bestavros96'), (671497, 'conf/vldb/AbiteboulAAACHHMMMMSTV99'), (276314, 'conf/sigmod/AgrawalGGR98'), (758382, 'conf/vldb/MargaritisFT01'), (959067, 'journals/sigmod/BonnetBDL03'), (219735, 'journals/sigmod/ElmagarmidJF95'), (671331, 'conf/vldb/IshikawaSF98'), (344825, 'journals/sigmod/GatziuJSV99'), (253287, 'conf/sigmod/AdelbergGW97'), (604282, 'journals/sigmod/ShahMFH01'), (223812, 'conf/sigmod/FaloutsosL95'), (187442, 'journals/sigmod/Datta94'), (344864, 'journals/sigmod/EisenbergM99a'), (673493, 'conf/vldb/KornSFSP96'), (959069, 'journals/sigmod/AilamakiFFSV03'), (244811, 'journals/tods/Keen97'), (671521, 'conf/vldb/PacittMS99'), (211994, 'journals/sigmod/AbiteboulH95'), (673163, 'conf/vldb/RahmM95'), (245906, 'journals/sigmod/Sidell96'), (673331, 'conf/vldb/LeeL96'), (776996, 'journals/sigmod/Nascimento03'), (672985, 'conf/vldb/BrownCC94'), (274461, 'jou ...
# 459

# %%
total_time = end_time_part2 - start_time_part2
print(f"Total running time: {total_time:.2f} seconds")
# Out:
# Total running time: 21.70 seconds
